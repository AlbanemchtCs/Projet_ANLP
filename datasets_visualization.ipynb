# %% [markdown]
# # Datasets visualization

# %% [markdown]
# ## Connection to GoogleDrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Library installation

# %%
# !pip install datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.10.1-py3-none-any.whl (469 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 KB 29.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from datasets) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from datasets) (23.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (2.27.1)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 KB 15.7 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0.0,>=0.2.0
#   Downloading huggingface_hub-0.13.2-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 23.8 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (2023.3.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from datasets) (1.4.4)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 22.8 MB/s eta 0:00:00
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 49.5 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (9.0.0)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (6.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (4.65.0)
# Collecting dill<0.3.7,>=0.3.0
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 12.9 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (2.0.12)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 18.9 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 13.4 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (22.2.0)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 26.4 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (3.10.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (1.26.15)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.15.0)
# Installing collected packages: xxhash, multidict, frozenlist, dill, async-timeout, yarl, responses, multiprocess, huggingface-hub, aiosignal, aiohttp, datasets
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.10.1 dill-0.3.6 frozenlist-1.3.3 huggingface-hub-0.13.2 multidict-6.0.4 multiprocess-0.70.14 responses-0.18.0 xxhash-3.2.0 yarl-1.8.2

# %% [markdown]
# ## Dataset `dihana`

# %% [markdown]
# ### Import of the `dihana` dataset

# %%
import datasets
miam= '/content/drive/MyDrive/ANLP/projet_anlp/miam.py'

dataset = datasets.load_dataset('miam', 'dihana')
# Out:
# Downloading builder script:   0%|          | 0.00/15.8k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/22.8k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/15.7k [00:00<?, ?B/s]
# Downloading and preparing dataset miam/dihana to /root/.cache/huggingface/datasets/miam/dihana/1.0.0/3cb25c5337f9e60db1dc6d90344763a6ef79d7a4ac3c5f215ce6e8afe99db26c...
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/158k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/19.0k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/20.7k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/19063 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/2123 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2361 [00:00<?, ? examples/s]
# Dataset miam downloaded and prepared to /root/.cache/huggingface/datasets/miam/dihana/1.0.0/3cb25c5337f9e60db1dc6d90344763a6ef79d7a4ac3c5f215ce6e8afe99db26c. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ### Dataset `dihana` visualization

# %%
dataset['train'][2]
# Out:
# {'Speaker': 'U',
#  'Utterance': 'a Madrid',
#  'Dialogue_Act': 'Pregunta',
#  'Dialogue_ID': '1',
#  'File_ID': 'B209_BB2a0',
#  'Label': 9,
#  'Idx': 2}

# %%
dataset['train'].to_pandas()
# Out:
#       Speaker                                          Utterance  \
# 0           M  Bienvenido al servicio de información de trene...
# 1           U                      Hola , quería un viaje de ida
# 2           U                                           a Madrid
# 3           U                                el cinco de abril .
# 4           M                    ¿ Quiere salir desde madrid ? .
# ...       ...                                                ...
# 19058       U                               El tren más cómodo .
# 19059       M  El tren más rápido es un intercity que sale a ...
# 19060       M                                 Desea algo más ? .
# 19061       U                                               No .
# 19062       M  Gracias por utilizar este servicio . Feliz via...
#
#          Dialogue_Act Dialogue_ID     File_ID  Label    Idx
# 0            Apertura           1  B209_BB2a0      1      0
# 1            Pregunta           1  B209_BB2a0      9      1
# 2            Pregunta           1  B209_BB2a0      9      2
# 3            Pregunta           1  B209_BB2a0      9      3
# 4        Confirmacion           1  B209_BB2a0      3      4
# ...               ...         ...         ...    ...    ...
# 19058        Pregunta         899  B415_BA7a1      9  19058
# 19059       Respuesta         899  B415_BA7a1     10  19059
# 19060  Nueva_consulta         899  B415_BA7a1      8  19060
# 19061          Cierre         899  B415_BA7a1      2  19061
# 19062          Cierre         899  B415_BA7a1      2  19062
#
# [19063 rows x 7 columns]

# %% [markdown]
# ---
#
# **Distribution of labels in the dataset**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# create figure with three subplots
fig, axs = plt.subplots(1, 3, figsize=(20, 6))

# plot train data
chart = sns.countplot(x = dataset['train']["Dialogue_Act"], ax=axs[0])
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
axs[0].set_title("Train Data")

# plot validation data
chart = sns.countplot(x = dataset['validation']["Dialogue_Act"], ax=axs[1])
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
axs[1].set_title("Validation Data")

# plot test data
chart = sns.countplot(x = dataset['test']["Dialogue_Act"], ax=axs[2])
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
axs[2].set_title("Test Data")

# display the plot
plt.show()

# %% [markdown]
# We can observe a disproportion of the labels in all the splits of the `dihana` dataset. We would like to balance the labels afterwards.

# %% [markdown]
# ## Dataset `ilisten`

# %% [markdown]
# ### Import of the `ilisten` dataset

# %%
import datasets
miam= '/content/drive/MyDrive/ANLP/projet_anlp/miam.py'

dataset = datasets.load_dataset('miam', 'ilisten')
# Out:
# Downloading and preparing dataset miam/ilisten to /root/.cache/huggingface/datasets/miam/ilisten/1.0.0/3cb25c5337f9e60db1dc6d90344763a6ef79d7a4ac3c5f215ce6e8afe99db26c...
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/38.5k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.88k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/28.0k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1986 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/230 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/971 [00:00<?, ? examples/s]
# Dataset miam downloaded and prepared to /root/.cache/huggingface/datasets/miam/ilisten/1.0.0/3cb25c5337f9e60db1dc6d90344763a6ef79d7a4ac3c5f215ce6e8afe99db26c. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ### Dataset `ilisten` visualization

# %%
dataset['train'][2]
# Out:
# {'Speaker': 'U',
#  'Utterance': 'a Madrid',
#  'Dialogue_Act': 'Pregunta',
#  'Dialogue_ID': '1',
#  'File_ID': 'B209_BB2a0',
#  'Label': 9,
#  'Idx': 2}

# %%
dataset['train'].to_pandas()
# Out:
#        Speaker                                          Utterance  \
# 0      S_29_S1  Ciao, il mio nome e' Valentina. Sono qui per d...
# 1      S_29_U1  Ciao io sono Annamaria… eh… Ciao io sono Annam...
# 2      S_29_S2               Che cosa hai mangiato per colazione?
# 3      S_29_U2      Eh… una tazza di latte e caffè e una brioche.
# 4      S_29_S3                    Che cosa hai mangiato per cena?
# ...        ...                                                ...
# 1981  S_21_U19  Non mi fido della rete né tantomeno dei siti w...
# 1982  S_21_S20  Mi dispiace, non ho altri argomenti da utilizz...
# 1983  S_21_U20  Va bene, ti ringrazio, mi hai dato buoni consi...
# 1984  S_21_S21  E' stato davvero piacevole interagire con te. ...
# 1985  S_21_U21                     Grazie, vale lo stesso per te.
#
#                   Dialogue_Act Dialogue_ID  Label   Idx
# 0                      OPENING           0      8     0
# 1                      OPENING           0      8     1
# 2                     QUESTION           0     10     2
# 3                    STATEMENT           0     13     3
# 4                     QUESTION           0     10     4
# ...                        ...         ...    ...   ...
# 1981                    REJECT          39     11  1981
# 1982                    ANSWER          39      1  1982
# 1983  KIND-ATTITUDE_SMALL-TALK          39      6  1983
# 1984                   CLOSING          39      2  1984
# 1985  KIND-ATTITUDE_SMALL-TALK          39      6  1985
#
# [1986 rows x 6 columns]

# %% [markdown]
# ---
#
# **Distribution of labels in the dataset**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# create figure with three subplots
fig, axs = plt.subplots(1, 3, figsize=(20, 6))

# plot train data
chart = sns.countplot(x = dataset['train']["Dialogue_Act"], ax=axs[0])
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
axs[0].set_title("Train Data")

# plot validation data
chart = sns.countplot(x = dataset['validation']["Dialogue_Act"], ax=axs[1])
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
axs[1].set_title("Validation Data")

# plot test data
chart = sns.countplot(x = dataset['test']["Dialogue_Act"], ax=axs[2])
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
axs[2].set_title("Test Data")

# display the plot
plt.show()

# %% [markdown]
# We can observe a disproportion of the labels in all the splits of the `ilisten` dataset. We would like to balance the labels afterwards.

# %% [markdown]
# ## Dataset `loria`

# %% [markdown]
# ### Import of the `loria` dataset

# %%
import datasets
miam= '/content/drive/MyDrive/ANLP/projet_anlp/miam.py'

dataset = datasets.load_dataset('miam', 'loria')
# Out:
# Downloading builder script:   0%|          | 0.00/15.8k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/22.8k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/15.7k [00:00<?, ?B/s]
# Downloading and preparing dataset miam/loria to /root/.cache/huggingface/datasets/miam/loria/1.0.0/3cb25c5337f9e60db1dc6d90344763a6ef79d7a4ac3c5f215ce6e8afe99db26c...
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/171k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/21.4k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/21.4k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/8465 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/942 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1047 [00:00<?, ? examples/s]
# Dataset miam downloaded and prepared to /root/.cache/huggingface/datasets/miam/loria/1.0.0/3cb25c5337f9e60db1dc6d90344763a6ef79d7a4ac3c5f215ce6e8afe99db26c. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ### Dataset `loria` visualization

# %%
dataset['train'][2]
# Out:
# {'Speaker': 'Ben',
#  'Utterance': "Où est l'entreprise qu'on cherche ?",
#  'Dialogue_Act': 'help',
#  'Dialogue_ID': '0',
#  'File_ID': 'Dial_20110615_105040',
#  'Label': 6,
#  'Idx': 2}

# %%
dataset['train'].to_pandas()
# Out:
#       Speaker                                          Utterance Dialogue_Act  \
# 0       Lucas                                             Alors!        greet
# 1       Lucas  Il faut que tu trouves l' adresse de l' entrep...          ask
# 2         Ben                Où est l'entreprise qu'on cherche ?         help
# 3       Lucas  Je ne sais pas... mon oncle a dit que c' était...       inform
# 4       Lucas                                             Allez!         quit
# ...       ...                                                ...          ...
# 8460  Mélissa                      Bravo! Vous avez été rapides!        greet
# 8461  Mélissa             Qu'est-ce que je peux faire pour vous?          ask
# 8462    Lucas  Oui c'est ce qu'on me dit assez souvent. Bon i...    next_step
# 8463  Mélissa  d' abord, cherchez la machine qui convient sur...       inform
# 8464  Mélissa  une fois que vous aurez monté le moule dessus,...         quit
#
#      Dialogue_ID               File_ID  Label   Idx
# 0              0  Dial_20110615_105040      5     0
# 1              0  Dial_20110615_105040      1     1
# 2              0  Dial_20110615_105040      6     2
# 3              0  Dial_20110615_105040      7     3
# 4              0  Dial_20110615_105040     21     4
# ...          ...                   ...    ...   ...
# 8460        1248  Dial_20110616_133056      5  8460
# 8461        1248  Dial_20110616_133056      1  8461
# 8462        1248  Dial_20110616_133056     17  8462
# 8463        1248  Dial_20110616_133056      7  8463
# 8464        1248  Dial_20110616_133056     21  8464
#
# [8465 rows x 7 columns]

# %% [markdown]
# ---
#
# **Distribution of labels in the dataset**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# create figure with three subplots
fig, axs = plt.subplots(1, 3, figsize=(20, 6))

# plot train data
chart = sns.countplot(x = dataset['train']["Dialogue_Act"], ax=axs[0])
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
axs[0].set_title("Train Data")

# plot validation data
chart = sns.countplot(x = dataset['validation']["Dialogue_Act"], ax=axs[1])
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
axs[1].set_title("Validation Data")

# plot test data
chart = sns.countplot(x = dataset['test']["Dialogue_Act"], ax=axs[2])
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
axs[2].set_title("Test Data")

# display the plot
plt.show()

# %% [markdown]
# We can observe a disproportion of the labels in all the splits of the `loria` dataset. We would like to balance the labels afterwards.

# %% [markdown]
# ## Dataset `maptask`

# %% [markdown]
# ### Import of the `maptask` dataset

# %%
import datasets
miam= '/content/drive/MyDrive/ANLP/projet_anlp/miam.py'

dataset = datasets.load_dataset('miam', 'maptask')
# Out:
# Downloading and preparing dataset miam/maptask to /root/.cache/huggingface/datasets/miam/maptask/1.0.0/3cb25c5337f9e60db1dc6d90344763a6ef79d7a4ac3c5f215ce6e8afe99db26c...
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/238k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/49.5k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/50.5k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/25382 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/5221 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/5335 [00:00<?, ? examples/s]
# Dataset miam downloaded and prepared to /root/.cache/huggingface/datasets/miam/maptask/1.0.0/3cb25c5337f9e60db1dc6d90344763a6ef79d7a4ac3c5f215ce6e8afe99db26c. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ### Dataset `maptask` visualization

# %%
dataset['train'][2]
# Out:
# {'Speaker': 'g',
#  'Utterance': 'okay',
#  'Dialogue_Act': 'align',
#  'Dialogue_ID': '0',
#  'File_ID': 'q7nc7',
#  'Label': 1,
#  'Idx': 2}

# %%
dataset['train'].to_pandas()
# Out:
#       Speaker                                          Utterance Dialogue_Act  \
# 0           g  okay the start part is at the top left-hand co...     instruct
# 1           f                                             uh-huh  acknowledge
# 2           g                                               okay        align
# 3           f                                             uh-huh      reply_y
# 4           g  ehm you're coming the s-- for three inches dow...     instruct
# ...       ...                                                ...          ...
# 25377       g  well move from where you are now down to below...     instruct
# 25378       f                                               yeah  acknowledge
# 25379       g  and then up 'til and the finish is just here o...     instruct
# 25380       f                                               okay  acknowledge
# 25381       g                                               okay  acknowledge
#
#       Dialogue_ID File_ID  Label    Idx
# 0               0   q7nc7      5      0
# 1               0   q7nc7      0      1
# 2               0   q7nc7      1      2
# 3               0   q7nc7     11      3
# 4               0   q7nc7      5      4
# ...           ...     ...    ...    ...
# 25377         120   q2nc6      5  25377
# 25378         120   q2nc6      0  25378
# 25379         120   q2nc6      5  25379
# 25380         120   q2nc6      0  25380
# 25381         120   q2nc6      0  25381
#
# [25382 rows x 7 columns]

# %% [markdown]
# ---
#
# **Distribution of labels in the dataset**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# create figure with three subplots
fig, axs = plt.subplots(1, 3, figsize=(20, 6))

# plot train data
chart = sns.countplot(x = dataset['train']["Dialogue_Act"], ax=axs[0])
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
axs[0].set_title("Train Data")

# plot validation data
chart = sns.countplot(x = dataset['validation']["Dialogue_Act"], ax=axs[1])
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
axs[1].set_title("Validation Data")

# plot test data
chart = sns.countplot(x = dataset['test']["Dialogue_Act"], ax=axs[2])
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
axs[2].set_title("Test Data")

# display the plot
plt.show()

# %% [markdown]
# We can observe a disproportion of the labels in all the splits of the `maptask` dataset. We would like to balance the labels afterwards.

# %% [markdown]
# ## Dataset `vm2`

# %% [markdown]
# ### Import of the `vm2` dataset

# %%
import datasets
miam= '/content/drive/MyDrive/ANLP/projet_anlp/miam.py'

dataset = datasets.load_dataset('miam', 'vm2')
# Out:
# Downloading and preparing dataset miam/vm2 to /root/.cache/huggingface/datasets/miam/vm2/1.0.0/3cb25c5337f9e60db1dc6d90344763a6ef79d7a4ac3c5f215ce6e8afe99db26c...
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/167k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/18.8k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/18.6k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/25060 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/2860 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2855 [00:00<?, ? examples/s]
# Dataset miam downloaded and prepared to /root/.cache/huggingface/datasets/miam/vm2/1.0.0/3cb25c5337f9e60db1dc6d90344763a6ef79d7a4ac3c5f215ce6e8afe99db26c. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ### Dataset `vm2` visualization

# %%
dataset['train'][2]
# Out:
# {'Utterance': 'ja hallo Herr Keller',
#  'Dialogue_Act': 'GREET',
#  'Speaker': 'B',
#  'Dialogue_ID': '1',
#  'Label': 16,
#  'Idx': 2}

# %%
dataset['train'].to_pandas()
# Out:
#                                                Utterance       Dialogue_Act  \
# 0             mein Name ist Keller $K $E Doppel-$L $E $R          INTRODUCE
# 1      es geht um den Termin den wir für nächste Woch...               INIT
# 2                                   ja hallo Herr Keller              GREET
# 3             mein Name ist Mengele $M $E $N $G $E $L $E          INTRODUCE
# 4                    ja wir wollen doch ge nach Hannover               INIT
# ...                                                  ...                ...
# 25055            gut dann haben wir das ja jetzt geklärt              CLOSE
# 25056  dann können wir uns jetzt wieder in die Arbeit...             INFORM
# 25057                                                 ja  FEEDBACK_POSITIVE
# 25058                         schönen Dank Frau Matysiak              THANK
# 25059                          auf Wiedersehen Frau Lück                BYE
#
#       Speaker Dialogue_ID  Label    Idx
# 0           A           1     19      0
# 1           A           1     18      1
# 2           B           1     16      2
# 3           B           1     19      3
# 4           A           1     18      4
# ...       ...         ...    ...    ...
# 25055       A        5012      4  25055
# 25056       A        5012     17  25056
# 25057       B        5012     14  25057
# 25058       B        5012     30  25058
# 25059       A        5012      2  25059
#
# [25060 rows x 6 columns]

# %% [markdown]
# ---
#
# **Distribution of labels in the dataset**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# create figure with three subplots
fig, axs = plt.subplots(1, 3, figsize=(20, 6))

# plot train data
chart = sns.countplot(x = dataset['train']["Dialogue_Act"], ax=axs[0])
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
axs[0].set_title("Train Data")

# plot validation data
chart = sns.countplot(x = dataset['validation']["Dialogue_Act"], ax=axs[1])
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
axs[1].set_title("Validation Data")

# plot test data
chart = sns.countplot(x = dataset['test']["Dialogue_Act"], ax=axs[2])
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
axs[2].set_title("Test Data")

# display the plot
plt.show()

# %% [markdown]
# We can observe a disproportion of the labels in all the splits of the `vm2` dataset. We would like to balance the labels afterwards.
